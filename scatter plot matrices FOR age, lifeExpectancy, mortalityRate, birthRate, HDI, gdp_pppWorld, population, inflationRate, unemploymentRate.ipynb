# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas
from pandas.plotting import scatter_matrix

#read data
data = pandas.read_csv('age.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'age_0-14_years',
#        'age_15-64_years', 'age_over_64_years'],
#       dtype='object')

# %%
#specify columns that show relation retry3-1
scatter_matrix(data[['refugees', 'age_0-14_years', 'age_15-64_years', 'age_over_64_years']])
plt.show()

# %%
#read data
data = pandas.read_csv('lifeExpectancy.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'lifeExpectancy_female',
#        'lifeExpectancy_male', 'lifeExpectancy'],
#       dtype='object')

# %%
#specify columns that show relation retry3-2
scatter_matrix(data[['refugees', 'lifeExpectancy_female', 'lifeExpectancy_male', 'lifeExpectancy']])
plt.show()

# %%
#read data
data = pandas.read_csv('mortalityRate.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'mortalityRate'], dtype='object')

# %%
#specify columns that show relation retry3-
scatter_matrix(data[['refugees', 'mortalityRate']])
plt.show()

# %%
#read data
data = pandas.read_csv('birthRate.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'birthRate'], dtype='object')

# %%
#specify columns that show relation retry3-
scatter_matrix(data[['refugees', 'birthRate']])
plt.show()

# %%
#read data
data = pandas.read_csv('humanDevelopmentIndex.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'humanDevelopmentIndex'], dtype='object')

# %%
#specify columns that show relation retry3-5
scatter_matrix(data[['refugees', 'humanDevelopmentIndex']])
plt.show()

# %%
#read data
data = pandas.read_csv('gdp_pppWorld.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'gdp_pppWorld'], dtype='object')

# %%
#specify columns that show relation retry3-
scatter_matrix(data[['refugees', 'gdp_pppWorld']])
plt.show()

# %%
#read data
data = pandas.read_csv('gdp_value.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'gdp_value', 'Unnamed: 4'], dtype='object')

# %%
#specify columns that show relation retry3-
scatter_matrix(data[['refugees', 'gdp_value']])
plt.show()

# %%
#read data
data = pandas.read_csv('population.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'population', 'population_male',
#        'population_female', 'populationDensity'],
#       dtype='object')

# %%
#specify columns that show relation retry3-8
scatter_matrix(data[['refugees', 'population', 'population_male', 'population_female', 'populationDensity']])
plt.show()

# %%
#read data
data = pandas.read_csv('inflationRate.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'inflationRate'], dtype='object')

# %%
#specify columns that show relation retry3-9
scatter_matrix(data[['refugees', 'inflationRate']])
plt.show()

# %%
#read data
data = pandas.read_csv('unemploymentRate.csv')
column_list=data.columns
print(column_list)
# Out:
# Index(['year', 'originCountry', 'refugees', 'unemploymentRate'], dtype='object')

# %%
#specify columns that show relation retry3-9
scatter_matrix(data[['refugees', 'unemploymentRate']])
plt.show()

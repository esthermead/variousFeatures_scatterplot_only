# %%
from numpy import loadtxt, zeros, ones, array, linspace, logspace
from pylab import scatter, show, title, xlabel, ylabel, plot, contour

# %%
#Load the dataset
data = loadtxt('refugeeAndTerrorism_txt.txt', delimiter='\t')

# %%
#Plot the data terrorismCount by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Acts of Terrorism by Year')
xlabel('Year')
ylabel('Acts of Terrorism')
show()

# %%
#Plot the data terrorismCount_z by year
scatter(data[:, 0], data[:, 2], marker='o', c='b')
title('Acts of Terrorism_z by Year')
xlabel('Year')
ylabel('Acts of Terrorism_z')
show()

# %%
#Plot the data refugees by year
scatter(data[:, 0], data[:, 3], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data refugees_z by year
scatter(data[:, 0], data[:, 4], marker='o', c='b')
title('Refugees_z by Year')
xlabel('Year')
ylabel('Refugees_z')
show()

# %%
#Plot the data Refugees by Acts of Terrorism
scatter(data[:, 1], data[:, 3], marker='o', c='b')
title('Refugees by Acts of Terrorism')
xlabel('Acts of Terrorism')
ylabel('Refugees')
show()

# %%
#Plot the data Acts of Terrorism by Refugees
scatter(data[:, 3], data[:, 1], marker='o', c='b')
title('Acts of Terrorism by Refugees')
xlabel('Refugees')
ylabel('Acts of Terrorism')
show()

# %%
#Load the dataset
data = loadtxt('costOfLivingIndex_txt.txt', delimiter='\t')

#Plot the data refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data COLI by year
scatter(data[:, 0], data[:, 3], marker='o', c='b')
title('COLI by Year')
xlabel('Year')
ylabel('Cost of Living Index')
show()

# %%
#Plot the data Refugees by COLI
scatter(data[:, 3], data[:, 1], marker='o', c='b')
title('Refugees by COLI')
xlabel('Cost of Living Index')
ylabel('Refugees')
show()

# %%
#Plot the data Refugees by rentIndex
scatter(data[:, 4], data[:, 1], marker='o', c='b')
title('Refugees by Cost of Rent Index')
xlabel('Cost of Rent Index')
ylabel('Refugees')
show()

# %%
#Plot the data Refugees by costOfLivingPlusRentIndex
scatter(data[:, 5], data[:, 1], marker='o', c='b')
title('Refugees by Cost of Living Plus Rent Index')
xlabel('COL Plus Rent Index')
ylabel('Refugees')
show()

# %%
#Plot the data Refugees by groceriesIndex
scatter(data[:, 6], data[:, 1], marker='o', c='b')
title('Refugees by Cost of Groceries Index')
xlabel('Cost of Groceries Index')
ylabel('Refugees')
show()

# %%
#Plot the data Refugees by restaurantPriceIndex
scatter(data[:, 7], data[:, 1], marker='o', c='b')
title('Refugees by Restaurant Price Index')
xlabel('Restaurant Price Index')
ylabel('Refugees')
show()

# %%
#Plot the data Refugees by localPurchasingPowerIndex
scatter(data[:, 8], data[:, 1], marker='o', c='b')
title('Refugees by Local Purchasing Power Index')
xlabel('Local Purchasing Power Index')
ylabel('Refugees')
show()

# %%
#Load the dataset
data = loadtxt('SPI.txt', delimiter='\t')

#Plot the data refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_accessToBasicDrinkingWater
scatter(data[:, 3], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Access to Basic Drinking Water')
xlabel('Access to Basic Drinking Water')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_accessToPipedWater
scatter(data[:, 4], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Access to Piped Water')
xlabel('Access to Piped Water')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_accessToBasicSanitation
scatter(data[:, 5], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Access to Basic Sanitation')
xlabel('Access to Basic Sanitation')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_accessToElectricity
scatter(data[:, 6], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Access to Electricity')
xlabel('Access to Electricity')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_mobilePhoneSubscriptions
scatter(data[:, 7], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Mobile Phone Subscriptions')
xlabel('Mobile Phone Subscriptions')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_accessToIndependentMedia
scatter(data[:, 8], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Access to Independent Media')
xlabel('Access to Independent Media')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_accessToQualityHealthcare
scatter(data[:, 9], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Access to Quality Healthcare')
xlabel('Access to Quality Healthcare')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_politicalRights
scatter(data[:, 10], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Political Rights')
xlabel('Political Rights')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_freedomOfExpression
scatter(data[:, 11], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Freedom of Expression')
xlabel('Freedom of Expression')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_freedomOfReligion
scatter(data[:, 12], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Freedom of Religion')
xlabel('Freedom of Religion')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_accessToJustice
scatter(data[:, 13], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Access to Justice')
xlabel('Access to Justice')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_propertyRightsForWomen
scatter(data[:, 14], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Property Rights for Women')
xlabel('Property Rights for Women')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_corruption
scatter(data[:, 15], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Corruption')
xlabel('Corruption')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_discriminationAndViolenceAgainstMinorities
scatter(data[:, 16], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Discrimination & Violence Against Minorities')
xlabel('Discrimination & Violence Against Minorities')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by SPI_equalityOfPoliticalPowerByGender
scatter(data[:, 17], data[:, 1], marker='o', c='b')
title('Refugees by Social Progress Index - Equality of Political Power by Gender')
xlabel('Equality of Political Power by Gender')
ylabel('Refugees')
show()

# %%
#Plot the data refugees_z by SPI_corruption
scatter(data[:, 15], data[:, 2], marker='o', c='b')
title('Refugees by Social Progress Index - Corruption')
xlabel('Corruption')
ylabel('Refugees_z')
show()

# %%
#Load the dataset
data = loadtxt('WHI.txt', delimiter='\t')

# %%
#Plot the data refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - lifeLadder
scatter(data[:, 2], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - lifeLadder')
xlabel('World Happiness Index - lifeLadder')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - logGDPperCapita
scatter(data[:, 3], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - log of GDP per Capita')
xlabel('World Happiness Index - log of GDP per Capita')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - socialSupport
scatter(data[:, 4], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - Social Support')
xlabel('World Happiness Index - Social Support')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - healthyLifeExpectancyAtBirth
scatter(data[:, 5], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - Healthy Life Expectancy At Birth')
xlabel('World Happiness Index - Healthy Life Expectancy At Birth')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - freedomToMakeLifeChoices
scatter(data[:, 6], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - Freedom to Make Life Choices')
xlabel('World Happiness Index - Freedom to Make Life Choices')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - generosity
scatter(data[:, 7], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - Generosity')
xlabel('World Happiness Index - Generosity')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - perceptionsOfCorruption
scatter(data[:, 8], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - Perceptions of Corruption')
xlabel('World Happiness Index - Perceptions of Corruption')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - positiveAffect
scatter(data[:, 9], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - Positive Affect')
xlabel('World Happiness Index - Positive Affect')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - negativeAffect
scatter(data[:, 10], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - Negative Affect')
xlabel('World Happiness Index - Negative Affect')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by World Happiness Index - GINIofHouseholdIncome
scatter(data[:, 11], data[:, 1], marker='o', c='b')
title('Refugees by World Happiness Index - GINI of Household Income')
xlabel('World Happiness Index - GINI of Household Income')
ylabel('Refugees')
show()

# %%
#Load the dataset
data = loadtxt('population.txt', delimiter='\t')

# %%
#Plot the data refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by population
scatter(data[:, 2], data[:, 1], marker='o', c='b')
title('Refugees by Population')
xlabel('Population')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by population_male
scatter(data[:, 3], data[:, 1], marker='o', c='b')
title('Refugees by Male Population')
xlabel('Male Population')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by population_female
scatter(data[:, 4], data[:, 1], marker='o', c='b')
title('Refugees by Female Population')
xlabel('Female Population')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by populationDensity
scatter(data[:, 5], data[:, 1], marker='o', c='b')
title('Refugees by Population Density')
xlabel('Population Density')
ylabel('Refugees')
show()

# %%
#Load the dataset
data = loadtxt('population_z.txt', delimiter='\t')

# %%
#Plot the data refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data refugees_z by year
scatter(data[:, 0], data[:, 2], marker='o', c='b')
title('Refugees_z by Year')
xlabel('Year')
ylabel('Refugees_Z')
show()

# %%
#Plot the data refugees_Z by populationDensity
scatter(data[:, 6], data[:, 1], marker='o', c='b')
title('Refugees_z by Population Density')
xlabel('Population Density')
ylabel('Refugees_z')
show()

# %%
#Load the dataset
data = loadtxt('CPI.txt', delimiter='\t')

# %%
#Plot the data refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by CPI
scatter(data[:, 1], data[:, 2], marker='o', c='b')
title('Refugees by Corruption Perception Index')
xlabel('Corruption Perception Index')
ylabel('Refugees')
show()

# %%
#Load the dataset
data = loadtxt('GGGI.txt', delimiter='\t')

# %%
#Plot the data refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by GGGI
scatter(data[:, 1], data[:, 2], marker='o', c='b')
title('Refugees by Global Gender Gap Index')
xlabel('Global Gender Gap Index')
ylabel('Refugees')
show()

# %%
#Load the dataset
data = loadtxt('inflationRate.txt', delimiter='\t')

# %%
#Plot the data refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by inflationRate
scatter(data[:, 1], data[:, 2], marker='o', c='b')
title('Refugees by Inflation Rate')
xlabel('Inflation Rate')
ylabel('Refugees')
show()

# %%
#Load the dataset
data = loadtxt('gdp_value.txt', delimiter='\t')

# %%
#Plot the data refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Refugees by Year')
xlabel('Year')
ylabel('Refugees')
show()

# %%
#Plot the data refugees by gdp_value
scatter(data[:, 1], data[:, 2], marker='o', c='b')
title('Refugees by GDP Value')
xlabel('GDP Value')
ylabel('Refugees')
show()

# %%
#Load the dataset
data = loadtxt('sudan_try.txt', delimiter='\t')

# %%
#Plot the data sudan refugees by year
scatter(data[:, 0], data[:, 1], marker='o', c='b')
title('Sudan Refugees by Year')
xlabel('Year')
ylabel('Sudan Refugees')
show()

# %%
#Plot the data sudan refugees by unemploymentRate
scatter(data[:, 2], data[:, 1], marker='o', c='b')
title('Sudan Refugees by Unemployment Rate')
xlabel('Unemployment Rate')
ylabel('Sudan Refugees')
show()

# %%
#Plot the data sudan refugees by inflationRate
scatter(data[:, 3], data[:, 1], marker='o', c='b')
title('Sudan Refugees by Inflation Rate')
xlabel('Inflation Rate')
ylabel('Sudan Refugees')
show()

# %%
#Plot the data sudan refugees by gdp_pppWorld
scatter(data[:, 4], data[:, 1], marker='o', c='b')
title('Sudan Refugees by gdp_pppWorld')
xlabel('gdp_pppWorld')
ylabel('Sudan Refugees')
show()

# %%
#Plot the data sudan refugees by humanDevelopmentIndex
scatter(data[:, 5], data[:, 1], marker='o', c='b')
title('Sudan Refugees by Human Development Index')
xlabel('Human Development Index')
ylabel('Sudan Refugees')
show()

# %%
#Plot the data sudan refugees by mortalityRate
scatter(data[:, 6], data[:, 1], marker='o', c='b')
title('Sudan Refugees by Mortality Rate')
xlabel('Mortality Rate')
ylabel('Sudan Refugees')
show()

# %%
#Plot the data sudan refugees by population
scatter(data[:, 7], data[:, 1], marker='o', c='b')
title('Sudan Refugees by Population')
xlabel('Population')
ylabel('Sudan Refugees')
show()

# %%
#Plot the data sudan refugees by refugeesAsPercentOfPopulation
scatter(data[:, 8], data[:, 1], marker='o', c='b')
title('Sudan Refugees by refugeesAsPercentOfPopulation')
xlabel('refugeesAsPercentOfPopulation')
ylabel('Sudan Refugees')
show()
